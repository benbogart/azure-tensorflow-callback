# %% [markdown]
# # Notebook # 1
#
# This is the first notebook in the supporting material for the medium article [Train on Cloud GPUs with Azure Machine Learning SDK for Python](https://medium.com/p/967c99418df1/)
#
# For the sake of clarity all packages and modules are imported in the cells in which they are used.

# %% [markdown]
# # Download and inspect the Data
#
# The easiest way to get the data is to download the data from here using your browser:
# https://drive.google.com/drive/folders/0B3P9oO5A3RvSUW9qTG11Ul83TEE
#
# We aren't doing this with python because its cumbersome to overcome google's filesize warning.  Place the zip file in this working directory before continuing.

# %%
# unzip the files
import zipfile
with zipfile.ZipFile('dataset-resized.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
# take a look inside the new folder
import os

data_path = 'dataset-resized'
categories = [f for f in os.listdir(data_path) 
              if os.path.isdir(os.path.join(data_path, f))]
categories
# Out:
# ['paper', 'metal', 'cardboard', 'trash', 'glass', 'plastic']

# %%
# count the number of images in each category
image_paths = {}
for cat in categories:
    image_paths[cat] = os.listdir(os.path.join(data_path,cat))
    print('There are', len(os.listdir(os.path.join(data_path,cat))), 
          cat, 
          'images' )
# Out:
# There are 594 paper images
# There are 410 metal images
# There are 403 cardboard images
# There are 137 trash images
# There are 501 glass images
# There are 482 plastic images

# %%
# take a look at some of the images
# inspect random images

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

from tensorflow.keras.preprocessing.image import load_img

fig, axs = plt.subplots(1,4, figsize=(16,4))
                        
for ax in axs:
    # choose a random category
    cat = np.random.choice(categories)
    
    # choose a random image in that category
    file_name = np.random.choice(os.listdir(os.path.join(data_path,cat)))
    
    # load and display the image
    img = load_img(os.path.join(data_path,cat,file_name))
    ax.imshow(img)
    ax.set_title(file_name)

# %% [markdown]
# # Split into training and validation sets

# %%
# make directories
split_base = 'data'

os.makedirs(split_base, exist_ok=True)

# store the path of each folder and create directories
train_folder = os.path.join(split_base, 'train')
os.makedirs(train_folder, exist_ok=True)

val_folder = os.path.join(split_base, 'validation')
os.makedirs(val_folder, exist_ok=True)

# %%
# split the files in to train and validation sets
import shutil

# portion of images to be used for testing
val_portion = 0.10

# Split the data into training, validation, and split folders
for cat in categories:
    # get total number of files in this category
    num_files = len(image_paths[cat])
    
    # randomize the file order for this category
    np.random.shuffle(image_paths[cat])
    
    # set split boundries for validation and test
    val_boundry = int(np.floor(num_files * val_portion))
        
    # store boundries
    labels = {'validation': image_paths[cat][:val_boundry],
              'train': image_paths[cat][val_boundry:]}
    
    # loop through boundries and move copy files
    for label, files in labels.items():
        # create folder
        os.mkdir(os.path.join(split_base, label, cat))
        
        # copy files to the correct directory
        for file in files:
            shutil.copyfile(os.path.join(data_path, cat, file),
                            os.path.join(split_base, label, cat, file))

# %% [markdown]
# # Azure Setup

# %% [markdown]
# 4  Setup Azure
# In order to setup a workspace the following code should be run with your information substituted. This will have you authenticate and will allow store your connection information in the .azureml directory. All files run in this directory or its subdirectories will be able to access that config file for connecting to azure.
#
# If the workspace does not exist it will be automatically created.
#
# Replace `[your-subscription-id]` with your Azure subscription id.

# %%
from azureml.core import Workspace

subscription_id = '[your-subscription-id]'
resource_group = 'azure_trash_demo'
workspace_name = 'azure_trash_demo'
location='eastus'

ws = Workspace.create(workspace_name,
                             subscription_id=subscription_id, 
                             resource_group=resource_group,
                             location=location
)

ws.write_config(path='.azureml')
# Out:
# UserWarning: The resource group doesn't exist or was not provided. AzureML SDK is creating a resource group=azure_trash_demo in location=eastus using subscription=6b443b21-01ef-4f24-91c6-70c888c1cb50.
# Deploying StorageAccount with name azuretrastorageb950d1239.
# Deploying KeyVault with name azuretrakeyvault5d30b0ea.
# Deploying AppInsights with name azuretrainsights5184a7e8.
# Deployed AppInsights with name azuretrainsights5184a7e8. Took 1.91 seconds.
# Deployed KeyVault with name azuretrakeyvault5d30b0ea. Took 17.32 seconds.
# Deploying Workspace with name azure_trash_demo.
# Deployed StorageAccount with name azuretrastorageb950d1239. Took 21.83 seconds.
# Deployed Workspace with name azure_trash_demo. Took 19.32 seconds.

# %%
# get the workspace from the save workspace file
ws = Workspace.from_config()

# %% [markdown]
# ## Create Compute Target

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

# the name we are going to use to reference our cluster
compute_name = "gpu-cluster-NC6"

# the azure machine type 
vm_size = 'Standard_NC6_Promo'

# define the cluster and the max and min number of nodes
provisioning_config = AmlCompute.provisioning_configuration(vm_size = vm_size,
                                                            min_nodes = 0, 
                                                            max_nodes = 10)
# create the cluster
compute_target = ComputeTarget.create(ws, compute_name, provisioning_config)

# %% [markdown]
# ## Setup Run Enviorment

# %%
from azureml.core.environment import Environment
from azureml.core.conda_dependencies import CondaDependencies

# create an enviornment
env = Environment(name='waste-env-gpu')

# define packages for image
cd = CondaDependencies.create(pip_packages=['azureml-dataset-runtime[pandas,fuse]', 
                                            'azureml-defaults',
                                            'tensorflow==2.4.0', 
                                            'Pillow'],
                             conda_packages=['SciPy'])

env.python.conda_dependencies = cd

# Specify a docker image to use.
env.docker.base_image = (
    "mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04"
)

# Register environment to re-use later
env = env.register(workspace = ws)

# %% [markdown]
# ## Upload Data

# %%
datastore = ws.get_default_datastore()

# upload the data to the datastore
datastore.upload(src_dir='data/',
                 target_path='/data/',
                 overwrite=False,
                 show_progress=True)
# Out:
# Uploading an estimated of 2527 files
# Uploading data/train/paper/paper297.jpg
# Uploaded data/train/paper/paper297.jpg, 1 files out of an estimated total of 2527
# Uploading data/train/paper/paper526.jpg
# Uploaded data/train/paper/paper526.jpg, 2 files out of an estimated total of 2527
# Uploading data/train/paper/paper240.jpg
# Uploaded data/train/paper/paper240.jpg, 3 files out of an estimated total of 2527
# Uploading data/train/paper/paper254.jpg
# Uploaded data/train/paper/paper254.jpg, 4 files out of an estimated total of 2527
# Uploading data/train/paper/paper532.jpg
# Uploaded data/train/paper/paper532.jpg, 5 files out of an estimated total of 2527
# Uploading data/train/paper/paper268.jpg
# Uploaded data/train/paper/paper268.jpg, 6 files out of an estimated total of 2527
# Uploading data/train/paper/paper491.jpg
# Uploaded data/train/paper/paper491.jpg, 7 files out of an estimated total of 2527
# Uploading data/train/paper/paper64.jpg
# Uploaded data/train/paper/paper64.jpg, 8 files out of an estimated total of 2527
# Uploading data/train/paper/paper70.jpg
# Uploaded data/train/paper/paper70.jpg, 9 files out of an estimated total of 2527
# Uploading data/train/paper/paper485.jpg
# Uploaded data/train/paper/paper485.jpg, 10 files out of an estimated total of 2527
# Uploading data/train/paper/paper58.jpg
# Uploaded data/train/paper/paper58.jpg, 11 files out of an estimated total of 2527
# Uploading data/train/paper/paper452.jpg
# Uploaded data/train/paper/paper452.jpg, 12 files out of an estimated total of 2527
# Uploading data/train/paper/paper334.jpg
# Uploaded data/train/paper/paper334.jpg, 13 files out of an estimated total of 2527
# Uploading data/train/paper/paper320.jpg
# Uploaded data/train/paper/paper320.jpg, 14 files out of an estimated total of 2527
# Uploading data/train/paper/paper308.jpg
# Uploaded data/train/paper/paper308.jpg, 15 files out of an estimated total of 2527
# Uploading data/train/paper/paper136.jpg
# Uploaded data/train/paper/paper136.jpg, 16 files out of an estimated total of 2527
# Uploading data/train/paper/paper122.jpg
# Uploaded data/train/paper/paper122.jpg, 17 files out of an estimated total of 2527
# Uploading data/train/paper/paper123.jpg
# Uploaded data/train/paper/paper123.jpg, 18 files out of an estimated total of 2527
# Uploading data/train/paper/paper137.jpg
# Uploaded data/train/paper/paper137.jpg, 19 files out of an estimated total of 2527
# Uploading data/train/paper/paper309.jpg
# Uploaded data/train/paper/paper309.jpg, 20 files out of an estimated total of 2527
# Uploading data/train/paper/paper321.jpg
# Uploaded data/train/paper/paper321.jpg, 21 files out of an estimated total of 2527
# Uploading data/train/paper/paper447.jpg
# Uploaded data/train/paper/paper447.jpg, 22 files out of an estimated total of 2527
# Uploading data/train/paper/paper453.jpg
# Uploaded data/train/paper/paper453.jpg, 23 files out of an estimated total of 2527
# Uploading data/train/paper/paper335.jpg
# Uploaded data/train/paper/paper335.jpg, 24 files out of an estimated total of 2527
# Uploading data/train/paper/paper59.jpg
# Uploaded data/train/paper/paper59.jpg, 25 files out of an estimated total of 2527
# Uploading data/train/paper/paper484.jpg
# Uploaded data/train/paper/paper484.jpg, 26 files out of an estimated total of 2527
# Uploading data/train/paper/paper71.jpg
# Uploaded data/train/paper/paper71.jpg, 27 files out of an estimated total of 2527
# Uploading data/train/paper/paper65.jpg
# Uploaded data/train/paper/paper65.jpg, 28 files out of an estimated total of 2527
# Uploading data/train/paper/paper490.jpg
# Uploaded data/train/paper/paper490.jpg, 29 files out of an estimated total of 2527
# Uploading data/train/paper/paper269.jpg
# Uploaded data/train/paper/paper269.jpg, 30 files out of an estimated total of 2527
# Uploading data/train/paper/paper255.jpg
# Uploaded data/train/paper/paper255.jpg, 31 files out of an estimated total of 2527
# Uploading data/train/paper/paper533.jpg
# Uploaded data/train/paper/paper533.jpg, 32 files out of an estimated total of 2527
# Uploading data/train/paper/paper527.jpg
# Uploaded data/train/paper/paper527.jpg, 33 files out of an estimated total of 2527
# Uploading data/train/paper/paper241.jpg
# Uploaded data/train/paper/paper241.jpg, 34 files out of an estimated total of 2527
# Uploading data/train/paper/paper296.jpg
# Uploaded data/train/paper/paper296.jpg, 35 files out of an estimated total of 2527
# Uploading data/train/paper/paper282.jpg
# Uploaded data/train/paper/paper282.jpg, 36 files out of an estimated total of 2527
# Uploading data/train/paper/paper294.jpg
# Uploaded data/train/paper/paper294.jpg, 37 files out of an estimated total of 2527
# Uploading data/train/paper/paper280.jpg
# Uploaded data/train/paper/paper280.jpg, 38 files out of an estimated total of 2527
# Uploading data/train/paper/paper531.jpg
# Uploaded data/train/paper/paper531.jpg, 39 files out of an estimated total of 2527
# Uploading data/train/paper/paper257.jpg
# Uploaded data/train/paper/paper257.jpg, 40 files out of an estimated total of 2527
# Uploading data/train/paper/paper243.jpg
# Uploaded data/train/paper/paper243.jpg, 41 files out of an estimated total of 2527
# Uploading data/train/paper/paper519.jpg
# Uploaded data/train/paper/paper519.jpg, 42 files out of an estimated total of 2527
# Uploading data/train/paper/paper73.jpg
# Uploaded data/train/paper/paper73.jpg, 43 files out of an estimated total of 2527
# Uploading data/train/paper/paper486.jpg
# Uploaded data/train/paper/paper486.jpg, 44 files out of an estimated total of 2527
# Uploading data/train/paper/paper492.jpg
# Uploaded data/train/paper/paper492.jpg, 45 files out of an estimated total of 2527
# Uploading data/train/paper/paper67.jpg
# Uploaded data/train/paper/paper67.jpg, 46 files out of an estimated total of 2527
# Uploading data/train/paper/paper445.jpg
# Uploaded data/train/paper/paper445.jpg, 47 files out of an estimated total of 2527
# Uploading data/train/paper/paper323.jpg
# Uploaded data/train/paper/paper323.jpg, 48 files out of an estimated total of 2527
# Uploading data/train/paper/paper337.jpg
# Uploaded data/train/paper/paper337.jpg, 49 files out of an estimated total of 2527
# Uploading data/train/paper/paper451.jpg
# Uploaded data/train/paper/paper451.jpg, 50 files out of an estimated total of 2527
# Uploading data/train/paper/paper479.jpg
# Uploaded data/train/paper/paper479.jpg, 51 files out of an estimated total of 2527
# Uploading data/train/paper/paper98.jpg
# Uploaded data/train/paper/paper98.jpg, 52 files out of an estimated total of 2527
# Uploading data/train/paper/paper121.jpg
# Uploaded data/train/paper/paper121.jpg, 53 files out of an estimated total of 2527
# Uploading data/train/paper/paper135.jpg
# Uploaded data/train/paper/paper135.jpg, 54 files out of an estimated total of 2527
# Uploading data/train/paper/paper109.jpg
# Uploaded data/train/paper/paper109.jpg, 55 files out of an estimated total of 2527
# Uploading data/train/paper/paper108.jpg
# Uploaded data/train/paper/paper108.jpg, 56 files out of an estimated total of 2527
# Uploading data/train/paper/paper134.jpg
# Uploaded data/train/paper/paper134.jpg, 57 files out of an estimated total of 2527
# Uploading data/train/paper/paper120.jpg
# Uploaded data/train/paper/paper120.jpg, 58 files out of an estimated total of 2527
# Uploading data/train/paper/paper99.jpg
# Uploaded data/train/paper/paper99.jpg, 59 files out of an estimated total of 2527
# Uploading data/train/paper/paper478.jpg
# Uploaded data/train/paper/paper478.jpg, 60 files out of an estimated total of 2527
# Uploading data/train/paper/paper336.jpg
# Uploaded data/train/paper/paper336.jpg, 61 files out of an estimated total of 2527
# Uploading data/train/paper/paper450.jpg
# Uploaded data/train/paper/paper450.jpg, 62 files out of an estimated total of 2527
# Uploading data/train/paper/paper322.jpg
# Uploaded data/train/paper/paper322.jpg, 63 files out of an estimated total of 2527
# Uploading data/train/paper/paper66.jpg
# Uploaded data/train/paper/paper66.jpg, 64 files out of an estimated total of 2527
# Uploading data/train/paper/paper493.jpg
# Uploaded data/train/paper/paper493.jpg, 65 files out of an estimated total of 2527
# Uploading data/train/paper/paper487.jpg
# Uploaded data/train/paper/paper487.jpg, 66 files out of an estimated total of 2527
# Uploading data/train/paper/paper72.jpg
# Uploaded data/train/paper/paper72.jpg, 67 files out of an estimated total of 2527
# Uploading data/train/paper/paper518.jpg
# Uploaded data/train/paper/paper518.jpg, 68 files out of an estimated total of 2527
# Uploading data/train/paper/paper242.jpg
# Uploaded data/train/paper/paper242.jpg, 69 files out of an estimated total of 2527
# Uploading data/train/paper/paper524.jpg
# Uploaded data/train/paper/paper524.jpg, 70 files out of an estimated total of 2527
# Uploading data/train/paper/paper530.jpg
# Uploaded data/train/paper/paper530.jpg, 71 files out of an estimated total of 2527
# Uploading data/train/paper/paper256.jpg
# Uploaded data/train/paper/paper256.jpg, 72 files out of an estimated total of 2527
# Uploading data/train/paper/paper295.jpg
# Uploaded data/train/paper/paper295.jpg, 73 files out of an estimated total of 2527
# Uploading data/train/paper/paper291.jpg
# Uploaded data/train/paper/paper291.jpg, 74 files out of an estimated total of 2527
# Uploading data/train/paper/paper508.jpg
# Uploaded data/train/paper/paper508.jpg, 75 files out of an estimated total of 2527
# Uploading data/train/paper/paper252.jpg
# Uploaded data/train/paper/paper252.jpg, 76 files out of an estimated total of 2527
# Uploading data/train/paper/paper534.jpg
# Uploaded data/train/paper/paper534.jpg, 77 files out of an estimated total of 2527
# Uploading data/train/paper/paper520.jpg
# Uploaded data/train/paper/paper520.jpg, 78 files out of an estimated total of 2527
# Uploading data/train/paper/paper246.jpg
# Uploaded data/train/paper/paper246.jpg, 79 files out of an estimated total of 2527
# Uploading data/train/paper/paper76.jpg
# Uploaded data/train/paper/paper76.jpg, 80 files out of an estimated total of 2527
# Uploading data/train/paper/paper483.jpg
# Uploaded data/train/paper/paper483.jpg, 81 files out of an estimated total of 2527
# Uploading data/train/paper/paper497.jpg
# Uploaded data/train/paper/paper497.jpg, 82 files out of an estimated total of 2527
# Uploading data/train/paper/paper62.jpg
# Uploaded data/train/paper/paper62.jpg, 83 files out of an estimated total of 2527
# Uploading data/train/paper/paper89.jpg
# Uploaded data/train/paper/paper89.jpg, 84 files out of an estimated total of 2527
# Uploading data/train/paper/paper468.jpg
# Uploaded data/train/paper/paper468.jpg, 85 files out of an estimated total of 2527
# Uploading data/train/paper/paper326.jpg
# Uploaded data/train/paper/paper326.jpg, 86 files out of an estimated total of 2527
# Uploading data/train/paper/paper118.jpg
# Uploaded data/train/paper/paper118.jpg, 87 files out of an estimated total of 2527
# Uploading data/train/paper/paper124.jpg
# Uploaded data/train/paper/paper124.jpg, 88 files out of an estimated total of 2527
# Uploading data/train/paper/paper130.jpg
# Uploaded data/train/paper/paper130.jpg, 89 files out of an estimated total of 2527
# Uploading data/train/paper/paper131.jpg
# Uploaded data/train/paper/paper131.jpg, 90 files out of an estimated total of 2527
# Uploading data/train/paper/paper125.jpg
# Uploaded data/train/paper/paper125.jpg, 91 files out of an estimated total of 2527
# Uploading data/train/paper/paper119.jpg
# Uploaded data/train/paper/paper119.jpg, 92 files out of an estimated total of 2527
# Uploading data/train/paper/paper455.jpg
# Uploaded data/train/paper/paper455.jpg, 93 files out of an estimated total of 2527
# Uploading data/train/paper/paper333.jpg
# Uploaded data/train/paper/paper333.jpg, 94 files out of an estimated total of 2527
# Uploading data/train/paper/paper327.jpg
# Uploaded data/train/paper/paper327.jpg, 95 files out of an estimated total of 2527
# Uploading data/train/paper/paper441.jpg
# Uploaded data/train/paper/paper441.jpg, 96 files out of an estimated total of 2527
# Uploading data/train/paper/paper469.jpg
# Uploaded data/train/paper/paper469.jpg, 97 files out of an estimated total of 2527
# Uploading data/train/paper/paper63.jpg
# Uploaded data/train/paper/paper63.jpg, 98 files out of an estimated total of 2527
# Uploading data/train/paper/paper496.jpg
# Uploaded data/train/paper/paper496.jpg, 99 files out of an estimated total of 2527
# Uploading data/train/paper/paper482.jpg
# Uploaded data/train/paper/paper482.jpg, 100 files out of an estimated total of 2527
# Uploading data/train/paper/paper521.jpg
# Uploaded data/train/paper/paper521.jpg, 101 files out of an estimated total of 2527
# Uploading data/train/paper/paper535.jpg
# Uploaded data/train/paper/paper535.jpg, 102 files out of an estimated total of 2527
# Uploading data/train/paper/paper509.jpg
# Uploaded data/train/paper/paper509.jpg, 103 files out of an estimated total of 2527
# Uploading data/train/paper/paper284.jpg
# Uploaded data/train/paper/paper284.jpg, 104 files out of an estimated total of 2527
# Uploading data/train/paper/paper290.jpg
# Uploaded data/train/paper/paper290.jpg, 105 files out of an estimated total of 2527
# Uploading data/train/paper/paper286.jpg
# Uploaded data/train/paper/paper286.jpg, 106 files out of an estimated total of 2527
# Uploading data/train/paper/paper292.jpg
# Uploaded data/train/paper/paper292.jpg, 107 files out of an estimated total of 2527
# Uploading data/train/paper/paper279.jpg
# Uploaded data/train/paper/paper279.jpg, 108 files out of an estimated total of 2527
# Uploading data/train/paper/paper523.jpg
# Uploaded data/train/paper/paper523.jpg, 109 files out of an estimated total of 2527
# Uploading data/train/paper/paper537.jpg
# Uploaded data/train/paper/paper537.jpg, 110 files out of an estimated total of 2527
# Uploading data/train/paper/paper251.jpg
# Uploaded data/train/paper/paper251.jpg, 111 files out of an estimated total of 2527
# Uploading data/train/paper/paper49.jpg
# Uploaded data/train/paper/paper49.jpg, 112 files out of an estimated total of 2527
# Uploading data/train/paper/paper494.jpg
# Uploaded data/train/paper/paper494.jpg, 113 files out of an estimated total of 2527
# Uploading data/train/paper/paper61.jpg
# Uploaded data/train/paper/paper61.jpg, 114 files out of an estimated total of 2527
# Uploading data/train/paper/paper75.jpg
# Uploaded data/train/paper/paper75.jpg, 115 files out of an estimated total of 2527
# Uploading data/train/paper/paper480.jpg
# Uploaded data/train/paper/paper480.jpg, 116 files out of an estimated total of 2527
# Uploading data/train/paper/paper319.jpg
# Uploaded data/train/paper/paper319.jpg, 117 files out of an estimated total of 2527
# Uploading data/train/paper/paper331.jpg
# Uploaded data/train/paper/paper331.jpg, 118 files out of an estimated total of 2527
# Uploading data/train/paper/paper457.jpg
# Uploaded data/train/paper/paper457.jpg, 119 files out of an estimated total of 2527
# Uploading data/train/paper/paper443.jpg
# Uploaded data/train/paper/paper443.jpg, 120 files out of an estimated total of 2527
# Uploading data/train/paper/paper325.jpg
# Uploaded data/train/paper/paper325.jpg, 121 files out of an estimated total of 2527
# Uploading data/train/paper/paper133.jpg
# Uploaded data/train/paper/paper133.jpg, 122 files out of an estimated total of 2527
# Uploading data/train/paper/paper127.jpg
# Uploaded data/train/paper/paper127.jpg, 123 files out of an estimated total of 2527
# Uploading data/train/paper/paper126.jpg
# Uploaded data/train/paper/paper126.jpg, 124 files out of an estimated total of 2527
# Uploading data/train/paper/paper132.jpg
# Uploaded data/train/paper/paper132.jpg, 125 files out of an estimated total of 2527
# Uploading data/train/paper/paper324.jpg
# Uploaded data/train/paper/paper324.jpg, 126 files out of an estimated total of 2527
# Uploading data/train/paper/paper330.jpg
# Uploaded data/train/paper/paper330.jpg, 127 files out of an estimated total of 2527
# Uploading data/train/paper/paper456.jpg
# Uploaded data/train/paper/paper456.jpg, 128 files out of an estimated total of 2527
# Uploading data/train/paper/paper481.jpg
# Uploaded data/train/paper/paper481.jpg, 129 files out of an estimated total of 2527
# Uploading data/train/paper/paper74.jpg
# Uploaded data/train/paper/paper74.jpg, 130 files out of an estimated total of 2527
# Uploading data/train/paper/paper60.jpg
# Uploaded data/train/paper/paper60.jpg, 131 files out of an estimated total of 2527
# Uploading data/train/paper/paper495.jpg
# Uploaded data/train/paper/paper495.jpg, 132 files out of an estimated total of 2527
# Uploading data/train/paper/paper48.jpg
# Uploaded data/train/paper/paper48.jpg, 133 files out of an estimated total of 2527
# Uploading data/train/paper/paper536.jpg
# Uploaded data/train/paper/paper536.jpg, 134 files out of an estimated total of 2527
# Uploading data/train/paper/paper250.jpg
# Uploaded data/train/paper/paper250.jpg, 135 files out of an estimated total of 2527
# Uploading data/train/paper/paper244.jpg
# Uploaded data/train/paper/paper244.jpg, 136 files out of an estimated total of 2527
# Uploading data/train/paper/paper522.jpg
# Uploaded data/train/paper/paper522.jpg, 137 files out of an estimated total of 2527
# Uploading data/train/paper/paper278.jpg
# Uploaded data/train/paper/paper278.jpg, 138 files out of an estimated total of 2527
# Uploading data/train/paper/paper293.jpg
# Uploaded data/train/paper/paper293.jpg, 139 files out of an estimated total of 2527
# Uploading data/train/paper/paper287.jpg
# Uploaded data/train/paper/paper287.jpg, 140 files out of an estimated total of 2527
# Uploading data/train/paper/paper586.jpg
# Uploaded data/train/paper/paper586.jpg, 141 files out of an estimated total of 2527
# Uploading data/train/paper/paper592.jpg
# Uploaded data/train/paper/paper592.jpg, 142 files out of an estimated total of 2527
# Uploading data/train/paper/paper223.jpg
# Uploaded data/train/paper/paper223.jpg, 143 files out of an estimated total of 2527
# Uploading data/train/paper/paper545.jpg
# Uploaded data/train/paper/paper545.jpg, 144 files out of an estimated total of 2527
# Uploading data/train/paper/paper551.jpg
# Uploaded data/train/paper/paper551.jpg, 145 files out of an estimated total of 2527
# Uploading data/train/paper/paper237.jpg
# Uploaded data/train/paper/paper237.jpg, 146 files out of an estimated total of 2527
# Uploading data/train/paper/paper579.jpg
# Uploaded data/train/paper/paper579.jpg, 147 files out of an estimated total of 2527
# Uploading data/train/paper/paper394.jpg
# Uploaded data/train/paper/paper394.jpg, 148 files out of an estimated total of 2527
# Uploading data/train/paper/paper13.jpg
# Uploaded data/train/paper/paper13.jpg, 149 files out of an estimated total of 2527
# Uploading data/train/paper/paper357.jpg
# Uploaded data/train/paper/paper357.jpg, 150 files out of an estimated total of 2527
# Uploading data/train/paper/paper431.jpg
# Uploaded data/train/paper/paper431.jpg, 151 files out of an estimated total of 2527
# Uploading data/train/paper/paper425.jpg
# Uploaded data/train/paper/paper425.jpg, 152 files out of an estimated total of 2527
# Uploading data/train/paper/paper419.jpg
# Uploaded data/train/paper/paper419.jpg, 153 files out of an estimated total of 2527
# Uploading data/train/paper/paper196.jpg
# Uploaded data/train/paper/paper196.jpg, 154 files out of an estimated total of 2527
# Uploading data/train/paper/paper182.jpg
# Uploaded data/train/paper/paper182.jpg, 155 files out of an estimated total of 2527
# Uploading data/train/paper/paper155.jpg
# Uploaded data/train/paper/paper155.jpg, 156 files out of an estimated total of 2527
# Uploading data/train/paper/paper141.jpg
# Uploaded data/train/paper/paper141.jpg, 157 files out of an estimated total of 2527
# Uploading data/train/paper/paper4.jpg
# Uploaded data/train/paper/paper4.jpg, 158 files out of an estimated total of 2527
# Uploading data/train/paper/paper169.jpg
# Uploaded data/train/paper/paper169.jpg, 159 files out of an estimated total of 2527
# Uploading data/train/paper/paper168.jpg
# Uploaded data/train/paper/paper168.jpg, 160 files out of an estimated total of 2527
# Uploading data/train/paper/paper140.jpg
# Uploaded data/train/paper/paper140.jpg, 161 files out of an estimated total of 2527
# Uploading data/train/paper/paper5.jpg
# Uploaded data/train/paper/paper5.jpg, 162 files out of an estimated total of 2527
# Uploading data/train/paper/paper154.jpg
# Uploaded data/train/paper/paper154.jpg, 163 files out of an estimated total of 2527
# Uploading data/train/paper/paper183.jpg
# Uploaded data/train/paper/paper183.jpg, 164 files out of an estimated total of 2527
# Uploading data/train/paper/paper197.jpg
# Uploaded data/train/paper/paper197.jpg, 165 files out of an estimated total of 2527
# Uploading data/train/paper/paper418.jpg
# Uploaded data/train/paper/paper418.jpg, 166 files out of an estimated total of 2527
# Uploading data/train/paper/paper424.jpg
# Uploaded data/train/paper/paper424.jpg, 167 files out of an estimated total of 2527
# Uploading data/train/paper/paper342.jpg
# Uploaded data/train/paper/paper342.jpg, 168 files out of an estimated total of 2527
# Uploading data/train/paper/paper356.jpg
# Uploaded data/train/paper/paper356.jpg, 169 files out of an estimated total of 2527
# Uploading data/train/paper/paper430.jpg
# Uploaded data/train/paper/paper430.jpg, 170 files out of an estimated total of 2527
# Uploading data/train/paper/paper12.jpg
# Uploaded data/train/paper/paper12.jpg, 171 files out of an estimated total of 2527
# Uploading data/train/paper/paper381.jpg
# Uploaded data/train/paper/paper381.jpg, 172 files out of an estimated total of 2527
# Uploading data/train/paper/paper395.jpg
# Uploaded data/train/paper/paper395.jpg, 173 files out of an estimated total of 2527
# Uploading data/train/paper/paper550.jpg
# Uploaded data/train/paper/paper550.jpg, 174 files out of an estimated total of 2527
# Uploading data/train/paper/paper236.jpg
# Uploaded data/train/paper/paper236.jpg, 175 files out of an estimated total of 2527
# Uploading data/train/paper/paper222.jpg
# Uploaded data/train/paper/paper222.jpg, 176 files out of an estimated total of 2527
# Uploading data/train/paper/paper544.jpg
# Uploaded data/train/paper/paper544.jpg, 177 files out of an estimated total of 2527
# Uploading data/train/paper/paper593.jpg
# Uploaded data/train/paper/paper593.jpg, 178 files out of an estimated total of 2527
# Uploading data/train/paper/paper587.jpg
# Uploaded data/train/paper/paper587.jpg, 179 files out of an estimated total of 2527
# Uploading data/train/paper/paper591.jpg
# Uploaded data/train/paper/paper591.jpg, 180 files out of an estimated total of 2527
# Uploading data/train/paper/paper585.jpg
# Uploaded data/train/paper/paper585.jpg, 181 files out of an estimated total of 2527
# Uploading data/train/paper/paper234.jpg
# Uploaded data/train/paper/paper234.jpg, 182 files out of an estimated total of 2527
# Uploading data/train/paper/paper552.jpg
# Uploaded data/train/paper/paper552.jpg, 183 files out of an estimated total of 2527
# Uploading data/train/paper/paper546.jpg
# Uploaded data/train/paper/paper546.jpg, 184 files out of an estimated total of 2527
# Uploading data/train/paper/paper220.jpg
# Uploaded data/train/paper/paper220.jpg, 185 files out of an estimated total of 2527
# Uploading data/train/paper/paper383.jpg
# Uploaded data/train/paper/paper383.jpg, 186 files out of an estimated total of 2527
# Uploading data/train/paper/paper10.jpg
# Uploaded data/train/paper/paper10.jpg, 187 files out of an estimated total of 2527
# Uploading data/train/paper/paper397.jpg
# Uploaded data/train/paper/paper397.jpg, 188 files out of an estimated total of 2527
# Uploading data/train/paper/paper38.jpg
# Uploaded data/train/paper/paper38.jpg, 189 files out of an estimated total of 2527
# Uploading data/train/paper/paper340.jpg
# Uploaded data/train/paper/paper340.jpg, 190 files out of an estimated total of 2527
# Uploading data/train/paper/paper426.jpg
# Uploaded data/train/paper/paper426.jpg, 191 files out of an estimated total of 2527
# Uploading data/train/paper/paper432.jpg
# Uploaded data/train/paper/paper432.jpg, 192 files out of an estimated total of 2527
# Uploading data/train/paper/paper354.jpg
# Uploaded data/train/paper/paper354.jpg, 193 files out of an estimated total of 2527
# Uploading data/train/paper/paper368.jpg
# Uploaded data/train/paper/paper368.jpg, 194 files out of an estimated total of 2527
# Uploading data/train/paper/paper181.jpg
# Uploaded data/train/paper/paper181.jpg, 195 files out of an estimated total of 2527
# Uploading data/train/paper/paper195.jpg
# Uploaded data/train/paper/paper195.jpg, 196 files out of an estimated total of 2527
# Uploading data/train/paper/paper142.jpg
# Uploaded data/train/paper/paper142.jpg, 197 files out of an estimated total of 2527
# Uploading data/train/paper/paper156.jpg
# Uploaded data/train/paper/paper156.jpg, 198 files out of an estimated total of 2527
# Uploading data/train/paper/paper143.jpg
# Uploaded data/train/paper/paper143.jpg, 199 files out of an estimated total of 2527
# Uploading data/train/paper/paper194.jpg
# Uploaded data/train/paper/paper194.jpg, 200 files out of an estimated total of 2527
# Uploading data/train/paper/paper180.jpg
# Uploaded data/train/paper/paper180.jpg, 201 files out of an estimated total of 2527
# Uploading data/train/paper/paper369.jpg
# Uploaded data/train/paper/paper369.jpg, 202 files out of an estimated total of 2527
# Uploading data/train/paper/paper355.jpg
# Uploaded data/train/paper/paper355.jpg, 203 files out of an estimated total of 2527
# Uploading data/train/paper/paper341.jpg
# Uploaded data/train/paper/paper341.jpg, 204 files out of an estimated total of 2527
# Uploading data/train/paper/paper427.jpg
# Uploaded data/train/paper/paper427.jpg, 205 files out of an estimated total of 2527
# Uploading data/train/paper/paper39.jpg
# Uploaded data/train/paper/paper39.jpg, 206 files out of an estimated total of 2527
# Uploading data/train/paper/paper396.jpg
# Uploaded data/train/paper/paper396.jpg, 207 files out of an estimated total of 2527
# Uploading data/train/paper/paper382.jpg
# Uploaded data/train/paper/paper382.jpg, 208 files out of an estimated total of 2527
# Uploading data/train/paper/paper11.jpg
# Uploaded data/train/paper/paper11.jpg, 209 files out of an estimated total of 2527
# Uploading data/train/paper/paper209.jpg
# Uploaded data/train/paper/paper209.jpg, 210 files out of an estimated total of 2527
# Uploading data/train/paper/paper547.jpg
# Uploaded data/train/paper/paper547.jpg, 211 files out of an estimated total of 2527
# Uploading data/train/paper/paper221.jpg
# Uploaded data/train/paper/paper221.jpg, 212 files out of an estimated total of 2527
# Uploading data/train/paper/paper235.jpg
# Uploaded data/train/paper/paper235.jpg, 213 files out of an estimated total of 2527
# Uploading data/train/paper/paper553.jpg
# Uploaded data/train/paper/paper553.jpg, 214 files out of an estimated total of 2527
# Uploading data/train/paper/paper590.jpg
# Uploaded data/train/paper/paper590.jpg, 215 files out of an estimated total of 2527
# Uploading data/train/paper/paper594.jpg
# Uploaded data/train/paper/paper594.jpg, 216 files out of an estimated total of 2527
# Uploading data/train/paper/paper580.jpg
# Uploaded data/train/paper/paper580.jpg, 217 files out of an estimated total of 2527
# Uploading data/train/paper/paper219.jpg
# Uploaded data/train/paper/paper219.jpg, 218 files out of an estimated total of 2527
# Uploading data/train/paper/paper557.jpg
# Uploaded data/train/paper/paper557.jpg, 219 files out of an estimated total of 2527
# Uploading data/train/paper/paper231.jpg
# Uploaded data/train/paper/paper231.jpg, 220 files out of an estimated total of 2527
# Uploading data/train/paper/paper225.jpg
# Uploaded data/train/paper/paper225.jpg, 221 files out of an estimated total of 2527
# Uploading data/train/paper/paper543.jpg
# Uploaded data/train/paper/paper543.jpg, 222 files out of an estimated total of 2527
# Uploading data/train/paper/paper29.jpg
# Uploaded data/train/paper/paper29.jpg, 223 files out of an estimated total of 2527
# Uploading data/train/paper/paper15.jpg
# Uploaded data/train/paper/paper15.jpg, 224 files out of an estimated total of 2527
# Uploading data/train/paper/paper392.jpg
# Uploaded data/train/paper/paper392.jpg, 225 files out of an estimated total of 2527
# Uploading data/train/paper/paper379.jpg
# Uploaded data/train/paper/paper379.jpg, 226 files out of an estimated total of 2527
# Uploading data/train/paper/paper423.jpg
# Uploaded data/train/paper/paper423.jpg, 227 files out of an estimated total of 2527
# Uploading data/train/paper/paper345.jpg
# Uploaded data/train/paper/paper345.jpg, 228 files out of an estimated total of 2527
# Uploading data/train/paper/paper351.jpg
# Uploaded data/train/paper/paper351.jpg, 229 files out of an estimated total of 2527
# Uploading data/train/paper/paper437.jpg
# Uploaded data/train/paper/paper437.jpg, 230 files out of an estimated total of 2527
# Uploading data/train/paper/paper184.jpg
# Uploaded data/train/paper/paper184.jpg, 231 files out of an estimated total of 2527
# Uploading data/train/paper/paper190.jpg
# Uploaded data/train/paper/paper190.jpg, 232 files out of an estimated total of 2527
# Uploading data/train/paper/paper147.jpg
# Uploaded data/train/paper/paper147.jpg, 233 files out of an estimated total of 2527
# Uploading data/train/paper/paper2.jpg
# Uploaded data/train/paper/paper2.jpg, 234 files out of an estimated total of 2527
# Uploading data/train/paper/paper153.jpg
# Uploaded data/train/paper/paper153.jpg, 235 files out of an estimated total of 2527
# Uploading data/train/paper/paper152.jpg
# Uploaded data/train/paper/paper152.jpg, 236 files out of an estimated total of 2527
# Uploading data/train/paper/paper146.jpg
# Uploaded data/train/paper/paper146.jpg, 237 files out of an estimated total of 2527
# Uploading data/train/paper/paper191.jpg
# Uploaded data/train/paper/paper191.jpg, 238 files out of an estimated total of 2527
# Uploading data/train/paper/paper185.jpg
# Uploaded data/train/paper/paper185.jpg, 239 files out of an estimated total of 2527
# Uploading data/train/paper/paper436.jpg
# Uploaded data/train/paper/paper436.jpg, 240 files out of an estimated total of 2527
# Uploading data/train/paper/paper422.jpg
# Uploaded data/train/paper/paper422.jpg, 241 files out of an estimated total of 2527
# Uploading data/train/paper/paper344.jpg
# Uploaded data/train/paper/paper344.jpg, 242 files out of an estimated total of 2527
# Uploading data/train/paper/paper378.jpg
# Uploaded data/train/paper/paper378.jpg, 243 files out of an estimated total of 2527
# Uploading data/train/paper/paper393.jpg
# Uploaded data/train/paper/paper393.jpg, 244 files out of an estimated total of 2527
# Uploading data/train/paper/paper14.jpg
# Uploaded data/train/paper/paper14.jpg, 245 files out of an estimated total of 2527
# Uploading data/train/paper/paper387.jpg
# Uploaded data/train/paper/paper387.jpg, 246 files out of an estimated total of 2527
# Uploading data/train/paper/paper28.jpg
# Uploaded data/train/paper/paper28.jpg, 247 files out of an estimated total of 2527
# Uploading data/train/paper/paper542.jpg
# Uploaded data/train/paper/paper542.jpg, 248 files out of an estimated total of 2527
# Uploading data/train/paper/paper556.jpg
# Uploaded data/train/paper/paper556.jpg, 249 files out of an estimated total of 2527
# Uploading data/train/paper/paper230.jpg
# Uploaded data/train/paper/paper230.jpg, 250 files out of an estimated total of 2527
# Uploading data/train/paper/paper218.jpg
# Uploaded data/train/paper/paper218.jpg, 251 files out of an estimated total of 2527
# Uploading data/train/paper/paper581.jpg
# Uploaded data/train/paper/paper581.jpg, 252 files out of an estimated total of 2527
# Uploading data/train/paper/paper583.jpg
# Uploaded data/train/paper/paper583.jpg, 253 files out of an estimated total of 2527
# Uploading data/train/paper/paper568.jpg
# Uploaded data/train/paper/paper568.jpg, 254 files out of an estimated total of 2527
# Uploading data/train/paper/paper540.jpg
# Uploaded data/train/paper/paper540.jpg, 255 files out of an estimated total of 2527
# Uploading data/train/paper/paper232.jpg
# Uploaded data/train/paper/paper232.jpg, 256 files out of an estimated total of 2527
# Uploading data/train/paper/paper554.jpg
# Uploaded data/train/paper/paper554.jpg, 257 files out of an estimated total of 2527
# Uploading data/train/paper/paper391.jpg
# Uploaded data/train/paper/paper391.jpg, 258 files out of an estimated total of 2527
# Uploading data/train/paper/paper385.jpg
# Uploaded data/train/paper/paper385.jpg, 259 files out of an estimated total of 2527
# Uploading data/train/paper/paper16.jpg
# Uploaded data/train/paper/paper16.jpg, 260 files out of an estimated total of 2527
# Uploading data/train/paper/paper408.jpg
# Uploaded data/train/paper/paper408.jpg, 261 files out of an estimated total of 2527
# Uploading data/train/paper/paper434.jpg
# Uploaded data/train/paper/paper434.jpg, 262 files out of an estimated total of 2527
# Uploading data/train/paper/paper352.jpg
# Uploaded data/train/paper/paper352.jpg, 263 files out of an estimated total of 2527
# Uploading data/train/paper/paper346.jpg
# Uploaded data/train/paper/paper346.jpg, 264 files out of an estimated total of 2527
# Uploading data/train/paper/paper420.jpg
# Uploaded data/train/paper/paper420.jpg, 265 files out of an estimated total of 2527
# Uploading data/train/paper/paper193.jpg
# Uploaded data/train/paper/paper193.jpg, 266 files out of an estimated total of 2527
# Uploading data/train/paper/paper187.jpg
# Uploaded data/train/paper/paper187.jpg, 267 files out of an estimated total of 2527
# Uploading data/train/paper/paper178.jpg
# Uploaded data/train/paper/paper178.jpg, 268 files out of an estimated total of 2527
# Uploading data/train/paper/paper150.jpg
# Uploaded data/train/paper/paper150.jpg, 269 files out of an estimated total of 2527
# Uploading data/train/paper/paper1.jpg
# Uploaded data/train/paper/paper1.jpg, 270 files out of an estimated total of 2527
# Uploading data/train/paper/paper144.jpg
# Uploaded data/train/paper/paper144.jpg, 271 files out of an estimated total of 2527
# Uploading data/train/paper/paper145.jpg
# Uploaded data/train/paper/paper145.jpg, 272 files out of an estimated total of 2527
# Uploading data/train/paper/paper151.jpg
# Uploaded data/train/paper/paper151.jpg, 273 files out of an estimated total of 2527
# Uploading data/train/paper/paper179.jpg
# Uploaded data/train/paper/paper179.jpg, 274 files out of an estimated total of 2527
# Uploading data/train/paper/paper186.jpg
# Uploaded data/train/paper/paper186.jpg, 275 files out of an estimated total of 2527
# Uploading data/train/paper/paper347.jpg
# Uploaded data/train/paper/paper347.jpg, 276 files out of an estimated total of 2527
# Uploading data/train/paper/paper421.jpg
# Uploaded data/train/paper/paper421.jpg, 277 files out of an estimated total of 2527
# Uploading data/train/paper/paper435.jpg
# Uploaded data/train/paper/paper435.jpg, 278 files out of an estimated total of 2527
# Uploading data/train/paper/paper353.jpg
# Uploaded data/train/paper/paper353.jpg, 279 files out of an estimated total of 2527
# Uploading data/train/paper/paper17.jpg
# Uploaded data/train/paper/paper17.jpg, 280 files out of an estimated total of 2527
# Uploading data/train/paper/paper390.jpg
# Uploaded data/train/paper/paper390.jpg, 281 files out of an estimated total of 2527
# Uploading data/train/paper/paper233.jpg
# Uploaded data/train/paper/paper233.jpg, 282 files out of an estimated total of 2527
# Uploading data/train/paper/paper555.jpg
# Uploaded data/train/paper/paper555.jpg, 283 files out of an estimated total of 2527
# Uploading data/train/paper/paper541.jpg
# Uploaded data/train/paper/paper541.jpg, 284 files out of an estimated total of 2527
# Uploading data/train/paper/paper227.jpg
# Uploaded data/train/paper/paper227.jpg, 285 files out of an estimated total of 2527
# Uploading data/train/paper/paper569.jpg
# Uploaded data/train/paper/paper569.jpg, 286 files out of an estimated total of 2527
# Uploading data/train/paper/paper582.jpg
# Uploaded data/train/paper/paper582.jpg, 287 files out of an estimated total of 2527
# Uploading data/train/paper/paper202.jpg
# Uploaded data/train/paper/paper202.jpg, 288 files out of an estimated total of 2527
# Uploading data/train/paper/paper564.jpg
# Uploaded data/train/paper/paper564.jpg, 289 files out of an estimated total of 2527
# Uploading data/train/paper/paper570.jpg
# Uploaded data/train/paper/paper570.jpg, 290 files out of an estimated total of 2527
# Uploading data/train/paper/paper216.jpg
# Uploaded data/train/paper/paper216.jpg, 291 files out of an estimated total of 2527
# Uploading data/train/paper/paper558.jpg
# Uploaded data/train/paper/paper558.jpg, 292 files out of an estimated total of 2527
# Uploading data/train/paper/paper26.jpg
# Uploaded data/train/paper/paper26.jpg, 293 files out of an estimated total of 2527
# Uploading data/train/paper/paper32.jpg
# Uploaded data/train/paper/paper32.jpg, 294 files out of an estimated total of 2527
# Uploading data/train/paper/paper389.jpg
# Uploaded data/train/paper/paper389.jpg, 295 files out of an estimated total of 2527
# Uploading data/train/paper/paper376.jpg
# Uploaded data/train/paper/paper376.jpg, 296 files out of an estimated total of 2527
# Uploading data/train/paper/paper404.jpg
# Uploaded data/train/paper/paper404.jpg, 297 files out of an estimated total of 2527
# Uploading data/train/paper/paper362.jpg
# Uploaded data/train/paper/paper362.jpg, 298 files out of an estimated total of 2527
# Uploading data/train/paper/paper438.jpg
# Uploaded data/train/paper/paper438.jpg, 299 files out of an estimated total of 2527
# Uploading data/train/paper/paper174.jpg
# Uploaded data/train/paper/paper174.jpg, 300 files out of an estimated total of 2527
# Uploading data/train/paper/paper160.jpg
# Uploaded data/train/paper/paper160.jpg, 301 files out of an estimated total of 2527
# Uploading data/train/paper/paper148.jpg
# Uploaded data/train/paper/paper148.jpg, 302 files out of an estimated total of 2527
# Uploading data/train/paper/paper149.jpg
# Uploaded data/train/paper/paper149.jpg, 303 files out of an estimated total of 2527
# Uploading data/train/paper/paper405.jpg
# Uploaded data/train/paper/paper405.jpg, 304 files out of an estimated total of 2527
# Uploading data/train/paper/paper363.jpg
# Uploaded data/train/paper/paper363.jpg, 305 files out of an estimated total of 2527
# Uploading data/train/paper/paper377.jpg
# Uploaded data/train/paper/paper377.jpg, 306 files out of an estimated total of 2527
# Uploading data/train/paper/paper411.jpg
# Uploaded data/train/paper/paper411.jpg, 307 files out of an estimated total of 2527
# Uploading data/train/paper/paper33.jpg
# Uploaded data/train/paper/paper33.jpg, 308 files out of an estimated total of 2527
# Uploading data/train/paper/paper27.jpg
# Uploaded data/train/paper/paper27.jpg, 309 files out of an estimated total of 2527
# Uploading data/train/paper/paper559.jpg
# Uploaded data/train/paper/paper559.jpg, 310 files out of an estimated total of 2527
# Uploading data/train/paper/paper571.jpg
# Uploaded data/train/paper/paper571.jpg, 311 files out of an estimated total of 2527
# Uploading data/train/paper/paper217.jpg
# Uploaded data/train/paper/paper217.jpg, 312 files out of an estimated total of 2527
# Uploading data/train/paper/paper565.jpg
# Uploaded data/train/paper/paper565.jpg, 313 files out of an estimated total of 2527
# Uploading data/train/paper/paper215.jpg
# Uploaded data/train/paper/paper215.jpg, 314 files out of an estimated total of 2527
# Uploading data/train/paper/paper573.jpg
# Uploaded data/train/paper/paper573.jpg, 315 files out of an estimated total of 2527
# Uploading data/train/paper/paper567.jpg
# Uploaded data/train/paper/paper567.jpg, 316 files out of an estimated total of 2527
# Uploading data/train/paper/paper201.jpg
# Uploaded data/train/paper/paper201.jpg, 317 files out of an estimated total of 2527
# Uploading data/train/paper/paper25.jpg
# Uploaded data/train/paper/paper25.jpg, 318 files out of an estimated total of 2527
# Uploading data/train/paper/paper19.jpg
# Uploaded data/train/paper/paper19.jpg, 319 files out of an estimated total of 2527
# Uploading data/train/paper/paper361.jpg
# Uploaded data/train/paper/paper361.jpg, 320 files out of an estimated total of 2527
# Uploading data/train/paper/paper407.jpg
# Uploaded data/train/paper/paper407.jpg, 321 files out of an estimated total of 2527
# Uploading data/train/paper/paper413.jpg
# Uploaded data/train/paper/paper413.jpg, 322 files out of an estimated total of 2527
# Uploading data/train/paper/paper375.jpg
# Uploaded data/train/paper/paper375.jpg, 323 files out of an estimated total of 2527
# Uploading data/train/paper/paper349.jpg
# Uploaded data/train/paper/paper349.jpg, 324 files out of an estimated total of 2527
# Uploading data/train/paper/paper188.jpg
# Uploaded data/train/paper/paper188.jpg, 325 files out of an estimated total of 2527
# Uploading data/train/paper/paper163.jpg
# Uploaded data/train/paper/paper163.jpg, 326 files out of an estimated total of 2527
# Uploading data/train/paper/paper177.jpg
# Uploaded data/train/paper/paper177.jpg, 327 files out of an estimated total of 2527
# Uploading data/train/paper/paper176.jpg
# Uploaded data/train/paper/paper176.jpg, 328 files out of an estimated total of 2527
# Uploading data/train/paper/paper162.jpg
# Uploaded data/train/paper/paper162.jpg, 329 files out of an estimated total of 2527
# Uploading data/train/paper/paper189.jpg
# Uploaded data/train/paper/paper189.jpg, 330 files out of an estimated total of 2527
# Uploading data/train/paper/paper348.jpg
# Uploaded data/train/paper/paper348.jpg, 331 files out of an estimated total of 2527
# Uploading data/train/paper/paper412.jpg
# Uploaded data/train/paper/paper412.jpg, 332 files out of an estimated total of 2527
# Uploading data/train/paper/paper374.jpg
# Uploaded data/train/paper/paper374.jpg, 333 files out of an estimated total of 2527
# Uploading data/train/paper/paper406.jpg
# Uploaded data/train/paper/paper406.jpg, 334 files out of an estimated total of 2527
# Uploading data/train/paper/paper18.jpg
# Uploaded data/train/paper/paper18.jpg, 335 files out of an estimated total of 2527
# Uploading data/train/paper/paper24.jpg
# Uploaded data/train/paper/paper24.jpg, 336 files out of an estimated total of 2527
# Uploading data/train/paper/paper30.jpg
# Uploaded data/train/paper/paper30.jpg, 337 files out of an estimated total of 2527
# Uploading data/train/paper/paper228.jpg
# Uploaded data/train/paper/paper228.jpg, 338 files out of an estimated total of 2527
# Uploading data/train/paper/paper566.jpg
# Uploaded data/train/paper/paper566.jpg, 339 files out of an estimated total of 2527
# Uploading data/train/paper/paper200.jpg
# Uploaded data/train/paper/paper200.jpg, 340 files out of an estimated total of 2527
# Uploading data/train/paper/paper214.jpg
# Uploaded data/train/paper/paper214.jpg, 341 files out of an estimated total of 2527
# Uploading data/train/paper/paper572.jpg
# Uploaded data/train/paper/paper572.jpg, 342 files out of an estimated total of 2527
# Uploading data/train/paper/paper589.jpg
# Uploaded data/train/paper/paper589.jpg, 343 files out of an estimated total of 2527
# Uploading data/train/paper/paper238.jpg
# Uploaded data/train/paper/paper238.jpg, 344 files out of an estimated total of 2527
# Uploading data/train/paper/paper576.jpg
# Uploaded data/train/paper/paper576.jpg, 345 files out of an estimated total of 2527
# Uploading data/train/paper/paper210.jpg
# Uploaded data/train/paper/paper210.jpg, 346 files out of an estimated total of 2527
# Uploading data/train/paper/paper204.jpg
# Uploaded data/train/paper/paper204.jpg, 347 files out of an estimated total of 2527
# Uploading data/train/paper/paper562.jpg
# Uploaded data/train/paper/paper562.jpg, 348 files out of an estimated total of 2527
# Uploading data/train/paper/paper20.jpg
# Uploaded data/train/paper/paper20.jpg, 349 files out of an estimated total of 2527
# Uploading data/train/paper/paper402.jpg
# Uploaded data/train/paper/paper402.jpg, 350 files out of an estimated total of 2527
# Uploading data/train/paper/paper364.jpg
# Uploaded data/train/paper/paper364.jpg, 351 files out of an estimated total of 2527
# Uploading data/train/paper/paper370.jpg
# Uploaded data/train/paper/paper370.jpg, 352 files out of an estimated total of 2527
# Uploading data/train/paper/paper416.jpg
# Uploaded data/train/paper/paper416.jpg, 353 files out of an estimated total of 2527
# Uploading data/train/paper/paper199.jpg
# Uploaded data/train/paper/paper199.jpg, 354 files out of an estimated total of 2527
# Uploading data/train/paper/paper166.jpg
# Uploaded data/train/paper/paper166.jpg, 355 files out of an estimated total of 2527
# Uploading data/train/paper/paper172.jpg
# Uploaded data/train/paper/paper172.jpg, 356 files out of an estimated total of 2527
# Uploading data/train/paper/paper173.jpg
# Uploaded data/train/paper/paper173.jpg, 357 files out of an estimated total of 2527
# Uploading data/train/paper/paper167.jpg
# Uploaded data/train/paper/paper167.jpg, 358 files out of an estimated total of 2527
# Uploading data/train/paper/paper198.jpg
# Uploaded data/train/paper/paper198.jpg, 359 files out of an estimated total of 2527
# Uploading data/train/paper/paper417.jpg
# Uploaded data/train/paper/paper417.jpg, 360 files out of an estimated total of 2527
# Uploading data/train/paper/paper403.jpg
# Uploaded data/train/paper/paper403.jpg, 361 files out of an estimated total of 2527
# Uploading data/train/paper/paper365.jpg
# Uploaded data/train/paper/paper365.jpg, 362 files out of an estimated total of 2527
# Uploading data/train/paper/paper359.jpg
# Uploaded data/train/paper/paper359.jpg, 363 files out of an estimated total of 2527
# Uploading data/train/paper/paper21.jpg
# Uploaded data/train/paper/paper21.jpg, 364 files out of an estimated total of 2527
# Uploading data/train/paper/paper35.jpg
# Uploaded data/train/paper/paper35.jpg, 365 files out of an estimated total of 2527
# Uploading data/train/paper/paper205.jpg
# Uploaded data/train/paper/paper205.jpg, 366 files out of an estimated total of 2527
# Uploading data/train/paper/paper563.jpg
# Uploaded data/train/paper/paper563.jpg, 367 files out of an estimated total of 2527
# Uploading data/train/paper/paper577.jpg
# Uploaded data/train/paper/paper577.jpg, 368 files out of an estimated total of 2527
# Uploading data/train/paper/paper211.jpg
# Uploaded data/train/paper/paper211.jpg, 369 files out of an estimated total of 2527
# Uploading data/train/paper/paper239.jpg
# Uploaded data/train/paper/paper239.jpg, 370 files out of an estimated total of 2527
# Uploading data/train/paper/paper588.jpg
# Uploaded data/train/paper/paper588.jpg, 371 files out of an estimated total of 2527
# Uploading data/train/paper/paper549.jpg
# Uploaded data/train/paper/paper549.jpg, 372 files out of an estimated total of 2527
# Uploading data/train/paper/paper561.jpg
# Uploaded data/train/paper/paper561.jpg, 373 files out of an estimated total of 2527
# Uploading data/train/paper/paper207.jpg
# Uploaded data/train/paper/paper207.jpg, 374 files out of an estimated total of 2527
# Uploading data/train/paper/paper213.jpg
# Uploaded data/train/paper/paper213.jpg, 375 files out of an estimated total of 2527
# Uploading data/train/paper/paper575.jpg
# Uploaded data/train/paper/paper575.jpg, 376 files out of an estimated total of 2527
# Uploading data/train/paper/paper398.jpg
# Uploaded data/train/paper/paper398.jpg, 377 files out of an estimated total of 2527
# Uploading data/train/paper/paper23.jpg
# Uploaded data/train/paper/paper23.jpg, 378 files out of an estimated total of 2527
# Uploading data/train/paper/paper37.jpg
# Uploaded data/train/paper/paper37.jpg, 379 files out of an estimated total of 2527
# Uploading data/train/paper/paper429.jpg
# Uploaded data/train/paper/paper429.jpg, 380 files out of an estimated total of 2527
# Uploading data/train/paper/paper415.jpg
# Uploaded data/train/paper/paper415.jpg, 381 files out of an estimated total of 2527
# Uploading data/train/paper/paper373.jpg
# Uploaded data/train/paper/paper373.jpg, 382 files out of an estimated total of 2527
# Uploading data/train/paper/paper367.jpg
# Uploaded data/train/paper/paper367.jpg, 383 files out of an estimated total of 2527
# Uploading data/train/paper/paper8.jpg
# Uploaded data/train/paper/paper8.jpg, 384 files out of an estimated total of 2527
# Uploading data/train/paper/paper159.jpg
# Uploaded data/train/paper/paper159.jpg, 385 files out of an estimated total of 2527
# Uploading data/train/paper/paper171.jpg
# Uploaded data/train/paper/paper171.jpg, 386 files out of an estimated total of 2527
# Uploading data/train/paper/paper165.jpg
# Uploaded data/train/paper/paper165.jpg, 387 files out of an estimated total of 2527
# Uploading data/train/paper/paper164.jpg
# Uploaded data/train/paper/paper164.jpg, 388 files out of an estimated total of 2527
# Uploading data/train/paper/paper170.jpg
# ...
# Uploading data/validation/cardboard/cardboard149.jpg
# Uploaded data/validation/cardboard/cardboard149.jpg, 2413 files out of an estimated total of 2527
# Uploading data/validation/cardboard/cardboard377.jpg
# Uploaded data/validation/cardboard/cardboard377.jpg, 2414 files out of an estimated total of 2527
# Uploading data/validation/cardboard/cardboard376.jpg
# Uploaded data/validation/cardboard/cardboard376.jpg, 2415 files out of an estimated total of 2527
# Uploading data/validation/cardboard/cardboard362.jpg
# Uploaded data/validation/cardboard/cardboard362.jpg, 2416 files out of an estimated total of 2527
# Uploading data/validation/trash/trash131.jpg
# Uploaded data/validation/trash/trash131.jpg, 2417 files out of an estimated total of 2527
# Uploading data/validation/trash/trash136.jpg
# Uploaded data/validation/trash/trash136.jpg, 2418 files out of an estimated total of 2527
# Uploading data/validation/trash/trash16.jpg
# Uploaded data/validation/trash/trash16.jpg, 2419 files out of an estimated total of 2527
# Uploading data/validation/trash/trash63.jpg
# Uploaded data/validation/trash/trash63.jpg, 2420 files out of an estimated total of 2527
# Uploading data/validation/trash/trash48.jpg
# Uploaded data/validation/trash/trash48.jpg, 2421 files out of an estimated total of 2527
# Uploading data/validation/trash/trash46.jpg
# Uploaded data/validation/trash/trash46.jpg, 2422 files out of an estimated total of 2527
# Uploading data/validation/trash/trash2.jpg
# Uploaded data/validation/trash/trash2.jpg, 2423 files out of an estimated total of 2527
# Uploading data/validation/trash/trash1.jpg
# Uploaded data/validation/trash/trash1.jpg, 2424 files out of an estimated total of 2527
# Uploading data/validation/trash/trash111.jpg
# Uploaded data/validation/trash/trash111.jpg, 2425 files out of an estimated total of 2527
# Uploading data/validation/trash/trash112.jpg
# Uploaded data/validation/trash/trash112.jpg, 2426 files out of an estimated total of 2527
# Uploading data/validation/trash/trash102.jpg
# Uploaded data/validation/trash/trash102.jpg, 2427 files out of an estimated total of 2527
# Uploading data/validation/trash/trash128.jpg
# Uploaded data/validation/trash/trash128.jpg, 2428 files out of an estimated total of 2527
# Uploading data/validation/trash/trash129.jpg
# Uploaded data/validation/trash/trash129.jpg, 2429 files out of an estimated total of 2527
# Uploading data/validation/glass/glass11.jpg
# Uploaded data/validation/glass/glass11.jpg, 2430 files out of an estimated total of 2527
# Uploading data/validation/glass/glass206.jpg
# Uploaded data/validation/glass/glass206.jpg, 2431 files out of an estimated total of 2527
# Uploading data/validation/glass/glass400.jpg
# Uploaded data/validation/glass/glass400.jpg, 2432 files out of an estimated total of 2527
# Uploading data/validation/glass/glass12.jpg
# Uploaded data/validation/glass/glass12.jpg, 2433 files out of an estimated total of 2527
# Uploading data/validation/glass/glass203.jpg
# Uploaded data/validation/glass/glass203.jpg, 2434 files out of an estimated total of 2527
# Uploading data/validation/glass/glass374.jpg
# Uploaded data/validation/glass/glass374.jpg, 2435 files out of an estimated total of 2527
# Uploading data/validation/glass/glass162.jpg
# Uploaded data/validation/glass/glass162.jpg, 2436 files out of an estimated total of 2527
# Uploading data/validation/glass/glass110.jpg
# Uploaded data/validation/glass/glass110.jpg, 2437 files out of an estimated total of 2527
# Uploading data/validation/glass/glass67.jpg
# Uploaded data/validation/glass/glass67.jpg, 2438 files out of an estimated total of 2527
# Uploading data/validation/glass/glass72.jpg
# Uploaded data/validation/glass/glass72.jpg, 2439 files out of an estimated total of 2527
# Uploading data/validation/glass/glass139.jpg
# Uploaded data/validation/glass/glass139.jpg, 2440 files out of an estimated total of 2527
# Uploading data/validation/glass/glass273.jpg
# Uploaded data/validation/glass/glass273.jpg, 2441 files out of an estimated total of 2527
# Uploading data/validation/glass/glass58.jpg
# Uploaded data/validation/glass/glass58.jpg, 2442 files out of an estimated total of 2527
# Uploading data/validation/glass/glass462.jpg
# Uploaded data/validation/glass/glass462.jpg, 2443 files out of an estimated total of 2527
# Uploading data/validation/glass/glass338.jpg
# Uploaded data/validation/glass/glass338.jpg, 2444 files out of an estimated total of 2527
# Uploading data/validation/glass/glass248.jpg
# Uploaded data/validation/glass/glass248.jpg, 2445 files out of an estimated total of 2527
# Uploading data/validation/glass/glass5.jpg
# Uploaded data/validation/glass/glass5.jpg, 2446 files out of an estimated total of 2527
# Uploading data/validation/glass/glass314.jpg
# Uploaded data/validation/glass/glass314.jpg, 2447 files out of an estimated total of 2527
# Uploading data/validation/glass/glass329.jpg
# Uploaded data/validation/glass/glass329.jpg, 2448 files out of an estimated total of 2527
# Uploading data/validation/glass/glass89.jpg
# Uploaded data/validation/glass/glass89.jpg, 2449 files out of an estimated total of 2527
# Uploading data/validation/glass/glass63.jpg
# Uploaded data/validation/glass/glass63.jpg, 2450 files out of an estimated total of 2527
# Uploading data/validation/glass/glass85.jpg
# Uploaded data/validation/glass/glass85.jpg, 2451 files out of an estimated total of 2527
# Uploading data/validation/glass/glass52.jpg
# Uploaded data/validation/glass/glass52.jpg, 2452 files out of an estimated total of 2527
# Uploading data/validation/glass/glass47.jpg
# Uploaded data/validation/glass/glass47.jpg, 2453 files out of an estimated total of 2527
# Uploading data/validation/glass/glass285.jpg
# Uploaded data/validation/glass/glass285.jpg, 2454 files out of an estimated total of 2527
# Uploading data/validation/glass/glass246.jpg
# Uploaded data/validation/glass/glass246.jpg, 2455 files out of an estimated total of 2527
# Uploading data/validation/glass/glass318.jpg
# Uploaded data/validation/glass/glass318.jpg, 2456 files out of an estimated total of 2527
# Uploading data/validation/glass/glass481.jpg
# Uploaded data/validation/glass/glass481.jpg, 2457 files out of an estimated total of 2527
# Uploading data/validation/glass/glass325.jpg
# Uploaded data/validation/glass/glass325.jpg, 2458 files out of an estimated total of 2527
# Uploading data/validation/glass/glass296.jpg
# Uploaded data/validation/glass/glass296.jpg, 2459 files out of an estimated total of 2527
# Uploading data/validation/glass/glass97.jpg
# Uploaded data/validation/glass/glass97.jpg, 2460 files out of an estimated total of 2527
# Uploading data/validation/glass/glass55.jpg
# Uploaded data/validation/glass/glass55.jpg, 2461 files out of an estimated total of 2527
# Uploading data/validation/glass/glass485.jpg
# Uploaded data/validation/glass/glass485.jpg, 2462 files out of an estimated total of 2527
# Uploading data/validation/glass/glass308.jpg
# Uploaded data/validation/glass/glass308.jpg, 2463 files out of an estimated total of 2527
# Uploading data/validation/glass/glass240.jpg
# Uploaded data/validation/glass/glass240.jpg, 2464 files out of an estimated total of 2527
# Uploading data/validation/glass/glass281.jpg
# Uploaded data/validation/glass/glass281.jpg, 2465 files out of an estimated total of 2527
# Uploading data/validation/glass/glass337.jpg
# Uploaded data/validation/glass/glass337.jpg, 2466 files out of an estimated total of 2527
# Uploading data/validation/glass/glass294.jpg
# Uploaded data/validation/glass/glass294.jpg, 2467 files out of an estimated total of 2527
# Uploading data/validation/glass/glass224.jpg
# Uploaded data/validation/glass/glass224.jpg, 2468 files out of an estimated total of 2527
# Uploading data/validation/glass/glass436.jpg
# Uploaded data/validation/glass/glass436.jpg, 2469 files out of an estimated total of 2527
# Uploading data/validation/glass/glass350.jpg
# Uploaded data/validation/glass/glass350.jpg, 2470 files out of an estimated total of 2527
# Uploading data/validation/glass/glass153.jpg
# Uploaded data/validation/glass/glass153.jpg, 2471 files out of an estimated total of 2527
# Uploading data/validation/glass/glass384.jpg
# Uploaded data/validation/glass/glass384.jpg, 2472 files out of an estimated total of 2527
# Uploading data/validation/glass/glass193.jpg
# Uploaded data/validation/glass/glass193.jpg, 2473 files out of an estimated total of 2527
# Uploading data/validation/glass/glass343.jpg
# Uploaded data/validation/glass/glass343.jpg, 2474 files out of an estimated total of 2527
# Uploading data/validation/glass/glass143.jpg
# Uploaded data/validation/glass/glass143.jpg, 2475 files out of an estimated total of 2527
# Uploading data/validation/glass/glass21.jpg
# Uploaded data/validation/glass/glass21.jpg, 2476 files out of an estimated total of 2527
# Uploading data/validation/glass/glass142.jpg
# Uploaded data/validation/glass/glass142.jpg, 2477 files out of an estimated total of 2527
# Uploading data/validation/glass/glass340.jpg
# Uploaded data/validation/glass/glass340.jpg, 2478 files out of an estimated total of 2527
# Uploading data/validation/glass/glass220.jpg
# Uploaded data/validation/glass/glass220.jpg, 2479 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic89.jpg
# Uploaded data/validation/plastic/plastic89.jpg, 2480 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic227.jpg
# Uploaded data/validation/plastic/plastic227.jpg, 2481 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic88.jpg
# Uploaded data/validation/plastic/plastic88.jpg, 2482 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic347.jpg
# Uploaded data/validation/plastic/plastic347.jpg, 2483 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic353.jpg
# Uploaded data/validation/plastic/plastic353.jpg, 2484 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic392.jpg
# Uploaded data/validation/plastic/plastic392.jpg, 2485 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic423.jpg
# Uploaded data/validation/plastic/plastic423.jpg, 2486 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic393.jpg
# Uploaded data/validation/plastic/plastic393.jpg, 2487 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic387.jpg
# Uploaded data/validation/plastic/plastic387.jpg, 2488 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic221.jpg
# Uploaded data/validation/plastic/plastic221.jpg, 2489 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic341.jpg
# Uploaded data/validation/plastic/plastic341.jpg, 2490 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic72.jpg
# Uploaded data/validation/plastic/plastic72.jpg, 2491 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic183.jpg
# Uploaded data/validation/plastic/plastic183.jpg, 2492 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic197.jpg
# Uploaded data/validation/plastic/plastic197.jpg, 2493 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic286.jpg
# Uploaded data/validation/plastic/plastic286.jpg, 2494 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic132.jpg
# Uploaded data/validation/plastic/plastic132.jpg, 2495 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic442.jpg
# Uploaded data/validation/plastic/plastic442.jpg, 2496 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic454.jpg
# Uploaded data/validation/plastic/plastic454.jpg, 2497 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic118.jpg
# Uploaded data/validation/plastic/plastic118.jpg, 2498 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic291.jpg
# Uploaded data/validation/plastic/plastic291.jpg, 2499 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic125.jpg
# Uploaded data/validation/plastic/plastic125.jpg, 2500 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic242.jpg
# Uploaded data/validation/plastic/plastic242.jpg, 2501 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic240.jpg
# Uploaded data/validation/plastic/plastic240.jpg, 2502 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic255.jpg
# Uploaded data/validation/plastic/plastic255.jpg, 2503 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic339.jpg
# Uploaded data/validation/plastic/plastic339.jpg, 2504 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic477.jpg
# Uploaded data/validation/plastic/plastic477.jpg, 2505 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic273.jpg
# Uploaded data/validation/plastic/plastic273.jpg, 2506 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic266.jpg
# Uploaded data/validation/plastic/plastic266.jpg, 2507 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic110.jpg
# Uploaded data/validation/plastic/plastic110.jpg, 2508 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic473.jpg
# Uploaded data/validation/plastic/plastic473.jpg, 2509 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic301.jpg
# Uploaded data/validation/plastic/plastic301.jpg, 2510 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic31.jpg
# Uploaded data/validation/plastic/plastic31.jpg, 2511 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic30.jpg
# Uploaded data/validation/plastic/plastic30.jpg, 2512 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic300.jpg
# Uploaded data/validation/plastic/plastic300.jpg, 2513 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic158.jpg
# Uploaded data/validation/plastic/plastic158.jpg, 2514 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic402.jpg
# Uploaded data/validation/plastic/plastic402.jpg, 2515 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic358.jpg
# Uploaded data/validation/plastic/plastic358.jpg, 2516 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic40.jpg
# Uploaded data/validation/plastic/plastic40.jpg, 2517 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic82.jpg
# Uploaded data/validation/plastic/plastic82.jpg, 2518 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic359.jpg
# Uploaded data/validation/plastic/plastic359.jpg, 2519 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic361.jpg
# Uploaded data/validation/plastic/plastic361.jpg, 2520 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic44.jpg
# Uploaded data/validation/plastic/plastic44.jpg, 2521 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic6.jpg
# Uploaded data/validation/plastic/plastic6.jpg, 2522 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic160.jpg
# Uploaded data/validation/plastic/plastic160.jpg, 2523 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic91.jpg
# Uploaded data/validation/plastic/plastic91.jpg, 2524 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic46.jpg
# Uploaded data/validation/plastic/plastic46.jpg, 2525 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic405.jpg
# Uploaded data/validation/plastic/plastic405.jpg, 2526 files out of an estimated total of 2527
# Uploading data/validation/plastic/plastic411.jpg
# Uploaded data/validation/plastic/plastic411.jpg, 2527 files out of an estimated total of 2527
# Uploaded 2527 files
# $AZUREML_DATAREFERENCE_f823f02eb8ec429a976bc23e6cc3cc9f

# %% [markdown]
# ## Create a Dataset
# A dataset is a reference to some data in a Datastore or on the internet.

# %%
from azureml.core import Dataset

# create the dataset object
dataset = Dataset.File.from_files(path=(datastore, '/data'))

# register the dataset for future use
dataset = dataset.register(workspace=ws,
                           name='waste_images',
                           description='Waste images divided into train/validation/split for classification')

# %% [markdown]
# # Continued in another notebook
# In order to demonstrate loading in the resources we created above we will continue in the next notebook:
# [2_Getting_started_with_Azure_for_Machine_Learning](2_Getting_started_with_Azure_for_Machine_Learning.ipynb)
